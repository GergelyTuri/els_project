# %%
from os import walk
from google.colab import drive
drive.mount('/gdrive')

from google.colab import files
# Out:
# Mounted at /gdrive

# %%
import glob

# %%
folders = '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/**/*/*.ffdd'

# %%
target = '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/**/*/*.csv'

# %%
to_download = glob.glob(folders, recursive=True)

# %%
for ffdd in to_download:
    files.download(ffdd)

# %%
glob.glob(target, recursive=True)
# Out:
# ['/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day1/export/freeze_Pat_Sep_day1.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day1/export/freeze_Pat_Sep_day1_custom.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day2/export/freeze_Pat_Sep_day2_final.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day3/afternoon/export/freeze_Pat_Sep_day2_A.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day3/morning/export/freeze_Pat_Sep_day3.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day5/morning/export/freeze_Pat_Sep_day5_A.csv',
#  '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/PTSD11_pattern_sep/PTSD11_shockboxes/PS_day5/afternoon/export/freeze_Pat_Sep_day5_B.csv',
# ...
