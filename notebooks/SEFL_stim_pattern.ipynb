# %% [markdown]
# stim pattern for analyzing ITI freezing

# %%
from os.path import join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = np.zeros(3600)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
out = '/gdrive/Shareddrives/TuriLab/Data/PTSD_project/!analysis/'

# %%
# preprogrammed 10 random shocks in freezframe
arr[292] = 1
arr[727] = 1
arr[1028] = 1
arr[1385] = 1
arr[1673] = 1
arr[1922] = 1
arr[2332] = 1
arr[2595] = 1
arr[3018] = 1
arr[3376] = 1

# %%
arr
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
arr[290:295]
# Out:
# array([0., 0., 1., 0., 0.])

# %%
plt.plot(arr)

# %%
np.savetxt(join(out, 'shock_series4.csv'), arr, delimiter=",", header='shocks')

# %%
bool_arr = np.full(3600, False)

# %%
# preprogrammed 10 random shocks in freezframe
bool_arr[292] = True
bool_arr[727] = True
bool_arr[1028] = True
bool_arr[1385] = True
bool_arr[1673] = True
bool_arr[1922] = True
bool_arr[2332] = True
bool_arr[2595] = True
bool_arr[3018] = True
bool_arr[3376] = True

# %%
np.savetxt(join(out, 'shock_series_bool.csv'), bool_arr, delimiter=",",
           header='shocks')
